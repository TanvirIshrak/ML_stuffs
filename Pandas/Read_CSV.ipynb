# %% [markdown]
# # Read CSV

# %%
import pandas as pd

csv_1 = pd.read_csv("D:\\Python learning sequence\\python for ML\\Pandas\\people-100.csv")
csv_1
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
csv_2 = pd.read_csv("D:\\Python learning sequence\\python for ML\\Pandas\\people-100.csv",nrows=3)
print(csv_2)
print(type(csv_2))
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title
# 0  001-084-906-7849x73518    1945-10-26  Games developer
# 1       214.112.6044x4913    1910-03-24   Phytotherapist
# 2            277.609.7938    1992-07-02        Homeopath
# <class 'pandas.core.frame.DataFrame'>

# %%
csv_2 = pd.read_csv("D:\\Python learning sequence\\python for ML\\Pandas\\people-100.csv",usecols=["First Name","Email"])
print(csv_2)                                                                                        # we can also pass col index here                          
print(type(csv_2))
# Out:
#    First Name                       Email
# 0      Shelby        elijah57@example.net
# 1     Phillip       bethany14@example.com
# 2    Kristine       bthompson@example.com
# 3     Yesenia   kaitlinkaiser@example.com
# 4        Lori  buchananmanuel@example.net
# ..        ...                         ...
# 95     Dennis         bmartin@example.org
# 96      Steve       latasha46@example.net
# 97     Wesley        regina11@example.org
# 98     Summer  alexiscantrell@example.org
# 99     Mariah       pcopeland@example.org
#
# [100 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
csv_2 = pd.read_csv("D:\\Python learning sequence\\python for ML\\Pandas\\people-100.csv",skiprows=[1])
print(csv_2)                                                                                                              
print(type(csv_2))
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 1       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 2       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 3       5  1bA7A3dc874da3c       Lori       Todd    Male
# 4       6  bfDD7CDEF5D865B       Erin        Day    Male
# ..    ...              ...        ...        ...     ...
# 94     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 95     97  CCbFce93d3720bE      Steve  Patterson  Female
# 96     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 97     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 98    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                  Phone Date of birth  \
# 0        bethany14@example.com      214.112.6044x4913    1910-03-24
# 1        bthompson@example.com           277.609.7938    1992-07-02
# 2    kaitlinkaiser@example.com           584.094.6111    2017-08-03
# ...

# %%
# customising column position
csv_1 = pd.read_csv("D:\\Python learning sequence\\python for ML\\Pandas\\people-100.csv",index_col="User Id")
csv_1
# Out:
#                  Index First Name  Last Name     Sex  \
# User Id
# 88F7B33d2bcf9f5      1     Shelby    Terrell    Male
# f90cD3E76f1A9b9      2    Phillip    Summers  Female
# DbeAb8CcdfeFC2c      3   Kristine     Travis    Male
# A31Bee3c201ef58      4    Yesenia   Martinez    Male
# 1bA7A3dc874da3c      5       Lori       Todd    Male
# ...                ...        ...        ...     ...
# 5eFda7caAeB260E     96     Dennis     Barnes  Female
# CCbFce93d3720bE     97      Steve  Patterson  Female
# 2fEc528aFAF0b69     98     Wesley       Bray    Male
# Adc7ad9B6e4A1Fe     99     Summer   Oconnell  Female
# b8D0aD3490FC7e1    100     Mariah    Bernard    Male
#
#                                       Email                   Phone  \
# User Id
# 88F7B33d2bcf9f5        elijah57@example.net  001-084-906-7849x73518
# f90cD3E76f1A9b9       bethany14@example.com       214.112.6044x4913
# DbeAb8CcdfeFC2c       bthompson@example.com            277.609.7938
# ...

# %%
# customising header
csv_1 = pd.read_csv("D:\\Python learning sequence\\python for ML\\Pandas\\people-100.csv",header=2)
csv_1
# Out:
#       2  f90cD3E76f1A9b9    Phillip    Summers  Female  \
# 0     3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 1     4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 2     5  1bA7A3dc874da3c       Lori       Todd    Male
# 3     6  bfDD7CDEF5D865B       Erin        Day    Male
# 4     7  bE9EEf34cB72AF7  Katherine       Buck  Female
# ..  ...              ...        ...        ...     ...
# 93   96  5eFda7caAeB260E     Dennis     Barnes  Female
# 94   97  CCbFce93d3720bE      Steve  Patterson  Female
# 95   98  2fEc528aFAF0b69     Wesley       Bray    Male
# 96   99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 97  100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#          bethany14@example.com      214.112.6044x4913  1910-03-24  \
# 0        bthompson@example.com           277.609.7938  1992-07-02
# 1    kaitlinkaiser@example.com           584.094.6111  2017-08-03
# 2   buchananmanuel@example.net      689-207-3558x7233  1938-12-01
# ...

# %%
# customising header
import pandas as pds
csv_3 = pds.read_csv("D:\\Python learning sequence\\python for ML\\Pandas\\people-100.csv",names=["col1","col2","col3"])
csv_3
# Out:
#                                                                                                 col1  \
# Index User Id         First Name Last Name Sex    Email                                        Phone
# 1     88F7B33d2bcf9f5 Shelby     Terrell   Male   elijah57@example.net        001-084-906-7849x73518
# 2     f90cD3E76f1A9b9 Phillip    Summers   Female bethany14@example.com            214.112.6044x4913
# 3     DbeAb8CcdfeFC2c Kristine   Travis    Male   bthompson@example.com                 277.609.7938
# 4     A31Bee3c201ef58 Yesenia    Martinez  Male   kaitlinkaiser@example.com             584.094.6111
# ...                                                                                              ...
# 96    5eFda7caAeB260E Dennis     Barnes    Female bmartin@example.org           001-095-524-2112x257
# 97    CCbFce93d3720bE Steve      Patterson Female latasha46@example.net             001-865-478-5157
# ...

# %%
# customising header
import pandas as pds
csv_3 = pds.read_csv("D:\\Python learning sequence\\python for ML\\Pandas\\people-100.csv",header=None)
csv_3 = csv_3.add_prefix("col")
csv_3
# Out:
#       col0             col1        col2       col3    col4  \
# 0    Index          User Id  First Name  Last Name     Sex
# 1        1  88F7B33d2bcf9f5      Shelby    Terrell    Male
# 2        2  f90cD3E76f1A9b9     Phillip    Summers  Female
# 3        3  DbeAb8CcdfeFC2c    Kristine     Travis    Male
# 4        4  A31Bee3c201ef58     Yesenia   Martinez    Male
# ..     ...              ...         ...        ...     ...
# 96      96  5eFda7caAeB260E      Dennis     Barnes  Female
# 97      97  CCbFce93d3720bE       Steve  Patterson  Female
# 98      98  2fEc528aFAF0b69      Wesley       Bray    Male
# 99      99  Adc7ad9B6e4A1Fe      Summer   Oconnell  Female
# 100    100  b8D0aD3490FC7e1      Mariah    Bernard    Male
#
#                            col5                    col6           col7  \
# 0                         Email                   Phone  Date of birth
# 1          elijah57@example.net  001-084-906-7849x73518     1945-10-26
# ...
