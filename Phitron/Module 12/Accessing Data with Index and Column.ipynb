# %%
import pandas as pd

df = pd.read_csv('student_data.csv')
print(df)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# accessing a column

type(df['FullName'])
# Out:
# pandas.core.series.Series

# %%
# loc[row (index) , column(features)]
# dc.loc[start:end , col_start,col_end]
print(df.loc[0])
print(type(df.loc[0]))
# Out:
# StudentID                    PH1001
# FullName                Alif Rahman
# Data Structure Marks           85.0
# Algorithm Marks                85.0
# Python Marks                   88.0
# CompletionStatus          Completed
# EnrollmentDate           2024-01-15
# Instructor                Mr. Karim
# Location                      Dhaka
# Name: 0, dtype: object
# <class 'pandas.core.series.Series'>

# %%
# multiple row (normal list)
df.loc[[2,3,19]]
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 19    PH1020        Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor Location
# 2           85.0        Completed     2024-02-10  Mr. Karim    Dhaka
# 3           82.0        Completed     2024-02-12  Ms. Salma   Sylhet
# 19          89.0        Completed     2025-10-02  Ms. Salma    Dhaka

# %%
# multiple row (range)
df.loc[3:5 , ]
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
# 5    PH1006       Laila Begum                  75.0             75.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# 5          78.0        Completed     2024-03-08  Ms. Salma    Rajshahi

# %%
# single column 
df.loc[ : , 'Python Marks']
# Out:
# 0     88.0
# 1      NaN
# 2     85.0
# 3     82.0
# 4     95.0
# 5     78.0
# 6      NaN
# 7     85.0
# 8     76.0
# 9     88.0
# 10    91.0
# 11    87.0
# 12    79.0
# 13     NaN
# 14    84.0
# 15     NaN
# 16    93.0
# 17    85.0
# 18     NaN
# 19    89.0
# Name: Python Marks, dtype: float64

# %%
# multiple columns
df.loc[:,['Python Marks','FullName']]
# Out:
#     Python Marks          FullName
# 0           88.0       Alif Rahman
# 1            NaN     Fatima Akhter
# 2           85.0     Imran Hossain
# 3           82.0  Jannatul Ferdous
# 4           95.0       Kamal Uddin
# 5           78.0       Laila Begum
# 6            NaN    Mahmudul Hasan
# 7           85.0       Nadia Islam
# 8           76.0        Omar Faruq
# 9           88.0      Priya Sharma
# 10          91.0      Rahim Sheikh
# 11          87.0   Sadia Chowdhury
# 12          79.0      Tanvir Ahmed
# 13           NaN        Urmi Akter
# 14          84.0      Wahiduzzaman
# 15           NaN      Ziaur Rahman
# 16          93.0       Afsana Mimi
# 17          85.0       Babul Ahmed
# 18           NaN      Faria Rahman
# 19          89.0        Nasir Khan

# %%
# row with columns
df.loc[3:7 , ['FullName','CompletionStatus']]
# Out:
#            FullName CompletionStatus
# 3  Jannatul Ferdous        Completed
# 4       Kamal Uddin      In Progress
# 5       Laila Begum        Completed
# 6    Mahmudul Hasan      In Progress
# 7       Nadia Islam        Completed
